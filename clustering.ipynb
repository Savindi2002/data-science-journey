# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch

# %%
df = pd.read_csv("customer_data.csv")
print(df.head())
# Out:
#    CustomerID  Age  AnnualIncome  SpendingScore
# 0           1   19            15             39
# 1           2   21            15             81
# 2           3   20            16              6
# 3           4   23            16             77
# 4           5   31            17             40

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerID     15 non-null     int64
#  1   Age            15 non-null     int64
#  2   AnnualIncome   15 non-null     int64
#  3   SpendingScore  15 non-null     int64
# dtypes: int64(4)
# memory usage: 612.0 bytes
# None
#        CustomerID        Age  AnnualIncome  SpendingScore
# count   15.000000  15.000000     15.000000      15.000000
# mean     8.000000  33.933333     18.266667      48.666667
# std      4.472136  16.206113      2.250926      34.576348
# min      1.000000  19.000000     15.000000       3.000000
# 25%      4.500000  22.500000     16.500000      14.500000
# 50%      8.000000  30.000000     18.000000      40.000000
# 75%     11.500000  36.000000     20.000000      76.500000
# max     15.000000  67.000000     22.000000      99.000000

# %%
df.columns = df.columns.str.replace(" ", "")
print(df.columns)
# Out:
# Index(['CustomerID', 'Age', 'AnnualIncome', 'SpendingScore'], dtype='object')

# %%
x = df.iloc[:, [2, 3]].values

# %%
plt.figure(figsize=(10, 6))
plt.title("Dendrogram")

sch.dendrogram(sch.linkage(x, method="ward"))

plt.xlabel("Customers")
plt.ylabel("Distance")
plt.show()
