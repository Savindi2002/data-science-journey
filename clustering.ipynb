# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch

# %%
df = pd.read_csv("Customer.csv")
print(df.head())
# Out:
#    CustomerID  Annual Income (k$)  Spending Score (1-100)
# 0           1                  15                      39
# 1           2                  16                      81
# 2           3                  17                       6
# 3           4                  18                      77
# 4           5                  19                      40

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              25 non-null     int64
#  1   Annual Income (k$)      25 non-null     int64
#  2   Spending Score (1-100)  25 non-null     int64
# dtypes: int64(3)
# memory usage: 732.0 bytes
# None
#        CustomerID  Annual Income (k$)  Spending Score (1-100)
# count   25.000000           25.000000               25.000000
# mean    13.000000           27.000000               50.080000
# std      7.359801            7.359801               30.693267
# min      1.000000           15.000000                3.000000
# 25%      7.000000           21.000000               29.000000
# 50%     13.000000           27.000000               45.000000
# 75%     19.000000           33.000000               77.000000
# ...
