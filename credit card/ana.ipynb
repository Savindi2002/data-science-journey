# %%
import pandas as pd
data = pd.read_csv("students.csv")
print(data.head())
# Out:
#    ID  StudyHours  SleepHours  Attendance  Marks
# 0   1           2           6          60     50
# 1   2           3           7          65     55
# 2   3           4           6          70     60
# 3   4           5           7          75     65
# 4   5           6           8          80     70

# %%
print(data.info())
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          50 non-null     int64
#  1   StudyHours  50 non-null     int64
#  2   SleepHours  50 non-null     int64
#  3   Attendance  50 non-null     int64
#  4   Marks       50 non-null     int64
# dtypes: int64(5)
# memory usage: 2.1 KB
# None
#              ID  StudyHours  SleepHours  Attendance      Marks
# count  50.00000    50.00000   50.000000   50.000000  50.000000
# mean   25.50000     5.14000    6.620000   71.560000  61.560000
# std    14.57738     2.16663    0.805339   10.868716  10.868716
# min     1.00000     2.00000    5.000000   53.000000  43.000000
# 25%    13.25000     3.00000    6.000000   62.250000  52.250000
# 50%    25.50000     5.00000    7.000000   70.500000  60.500000
# 75%    37.75000     7.00000    7.000000   80.000000  70.000000
# ...

# %%
print(data.isnull().sum())
# Out:
# ID            0
# StudyHours    0
# SleepHours    0
# Attendance    0
# Marks         0
# dtype: int64
