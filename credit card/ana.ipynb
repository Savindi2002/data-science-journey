# %%
import pandas as pd
data = pd.read_csv("students.csv")
print(data.head())
# Out:
#    ID  StudyHours  SleepHours  Attendance  Marks
# 0   1           2           6          60     50
# 1   2           3           7          65     55
# 2   3           4           6          70     60
# 3   4           5           7          75     65
# 4   5           6           8          80     70
